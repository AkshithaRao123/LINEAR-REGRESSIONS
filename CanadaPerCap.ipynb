# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshithaRao123/LINEAR-REGRESSIONS/blob/main/CanadaPerCap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/canada_per_capita_income.csv")
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     47 non-null     int64
#  1   per capita income (US$)  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 880.0 bytes

# %%
print(df.isnull().sum())
# Out:
# year                       0
# per capita income (US$)    0
# dtype: int64

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,1]
print(x,'\n',y)
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016
#  0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5      5998.144346
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    17266.097690
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.3,random_state=56)

# %%
xtrain
# Out:
#     year
# 13  1983
# 32  2002
# 29  1999
# 27  1997
# 38  2008
# 9   1979
# 37  2007
# 19  1989
# 44  2014
# 42  2012
# 31  2001
# 5   1975
# 10  1980
# 25  1995
# 1   1971
# 6   1976
# 46  2016
# 16  1986
# 11  1981
# 2   1972
# 12  1982
# 24  1994
# 26  1996
# 45  2015
# 22  1992
# 23  1993
# 14  1984
# 34  2004
# 0   1970
# 15  1985
# 36  2006
# 21  1991

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)
print(ypred)
# Out:
# [28112.41724786  5732.59385445 14524.66733043 22517.46139951
#   2535.47622682 13725.38792352 26513.85843405 16123.22614425
#  32908.09368931 32108.8142824   6531.87326136 34506.65250312
#  31309.53487549 24116.02021332  3334.75563372]

# %%
import matplotlib.pyplot as plt
plt.ylabel("Per capita income")
plt.xlabel("Year")
plt.plot(xtest,ypred)
plt.scatter(xtest,ytest)
plt.show()

# %%
model.coef_
# Out:
# array([799.27940691])

# %%
model.intercept_
# Out:
# -1574442.7936020812
